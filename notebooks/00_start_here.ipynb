# %% [markdown]
# # Start Here
#
# This project uses Jupyter notebooks for EDA and modeling.
#
# ## Recommended workflow
#
# 1. Open a terminal **in the project root** (the folder containing `data/`, `notebooks/`, and `src/`).
# 2. Activate the virtual environment.
# 3. Start Jupyter.
#
# ```bash
# source venv/bin/activate
# python -m pip install -r requirements.txt
# python -m pip install -e .
# jupyter lab
# ```
#
# ## Run order
#
# 1. `01_eda.ipynb`
# 2. `02_modeling.ipynb`

# %%
import sys
from pathlib import Path

print("Python:", sys.version)
print("Working directory:", Path.cwd())

# %%
# If this import fails, run: `python -m pip install -e .` from the project root.
import insurance_project

print("insurance_project imported from:", insurance_project.__file__)
